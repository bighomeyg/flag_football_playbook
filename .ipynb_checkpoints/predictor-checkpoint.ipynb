# %%
from PIL import Image
import numpy as np
import pandas as pd
from glob import glob
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def make_training_set(max_file):
    training_set = []
    labels = []
    for n in range(1,max_file):
        training_set.append("training_data/{}/data ({}).json".format(target_feature, str(n)))
        
    return training_set, label

# %%
def json_to_df(filename, canvas_height, canvas_width, color):
    ## Load in the file
    with open(filename) as f:
        data = json.load(f)
    training_route = data[color]
    
    ## Create and fill location matrix
    paths = pd.DataFrame(0, index=range(0,canvas_height),columns=range(0,canvas_width))
    for step in training_route:
        paths.set_value(np.round(step['y']), np.round(step['x']), 1)
        paths.set_value(np.round(step['y']) + 1, np.round(step['x']) + 1, 1)
        paths.set_value(np.round(step['y']) + 1, np.round(step['x']), 1)
        paths.set_value(np.round(step['y']) + 1, np.round(step['x']) - 1, 1)
        paths.set_value(np.round(step['y']), np.round(step['x']) + 1, 1)
        paths.set_value(np.round(step['y']), np.round(step['x']) - 1, 1)
        paths.set_value(np.round(step['y']) - 1, np.round(step['x']), 1)
        paths.set_value(np.round(step['y']) - 1, np.round(step['x']) - 1, 1)
        paths.set_value(np.round(step['y']) - 1, np.round(step['x']) + 1, 1)
        
    return paths

def center_df(df, canvas_height, canvas_width):
    ## Positions the receiver at the bottom center of the field
    ## This corresponds to the largest y-value
    
    bottom_of_route = 0
    for index, row in df.iterrows():
        if sum(row) > 0:
            bottom_of_route = index
            #print(bottom_of_route)
    
    
    
    for i,x in enumerate(df.ix[bottom_of_route]):
        if x != 0:
            lateral_translation = i
            
    df2 = pd.DataFrame(0, index=range(0,canvas_height),columns=range(0,canvas_width))
    df2.columns = [x for x in range(canvas_width,canvas_width*2)]
    df3 = df.join(df2)
    df3 = df3.shift(canvas_height-bottom_of_route, axis = 0).fillna(0)
    df3 = df3.shift(canvas_width-lateral_translation, axis = 1).fillna(0)
    
    return df3

# %%
def process_data(first_sample, last_sample, reverse):
    canvas_height = 400
    canvas_width = 600
    X = []
    Y = []
    for directory in glob('/Users/gstarek/Desktop/playbook/training_data/*'):
        playtype = directory.split("/")[-1]
        for n in range(first_sample, last_sample):
            fn = f'/Users/gstarek/Desktop/playbook/training_data/{playtype}/data ({n}).json'
            print(fn)
            df = json_to_df(fn, canvas_height, canvas_width, 'red')
            
            try:
                df = center_df(df, canvas_height, canvas_width)
                df.to_csv(f'/Users/gstarek/Desktop/playbook/training_data/{playtype}/right_{n}.csv')
                x = np.reshape(df.as_matrix(),canvas_height*canvas_width*2)
                X.append(x)
                Y.append(f"{playtype}_right")
                cols = df.columns
                if reverse == 'yes':
                    ## Create a mirror image DataFrame to run the play the other way
                    df = df[df.columns[::-1]]
                    df.columns = cols
                    df.to_csv(f'/Users/gstarek/Desktop/playbook/training_data/{playtype}/left_{n}.csv')
                    x = np.reshape(df.as_matrix(),canvas_height*canvas_width*2)
                    X.append(x)
                    ## The DataFrame is already centered and appropriately sized
                    #df = center_df(df, canvas_height, canvas_width)
                    #x = np.reshape(df.as_matrix(),canvas_height*canvas_width*2)
                    #X.append(x)
                    Y.append(f"{playtype}_left")
            except:
                print("Error")
                continue
    return X, Y

# %%
X, Y = process_data(1,80,reverse = 'yes')
# Out:
# /Users/gstarek/Desktop/playbook/training_data/posts/data (1).json
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   app.launch_new_instance()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/gstarek/Desktop/playbook/training_data/posts/data (2).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (3).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (4).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (5).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (6).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (7).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (8).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (9).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (10).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (11).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (12).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (13).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (14).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (15).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (16).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (17).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (18).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (19).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (20).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (21).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (22).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (23).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (24).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (25).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (26).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (27).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (28).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (29).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (30).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (31).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (32).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (33).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (34).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (35).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (36).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (37).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (38).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (39).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (40).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (41).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (42).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (43).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (44).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (45).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (46).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (47).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (48).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (49).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (50).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (51).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (52).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (53).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (54).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (55).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (56).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (57).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (58).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (59).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (60).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (61).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (62).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (63).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (64).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (65).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (66).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (67).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (68).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (69).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (70).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (71).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (72).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (73).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (74).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (75).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (76).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (77).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (78).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (79).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (1).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (2).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (3).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (4).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (5).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (6).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (7).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (8).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (9).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (10).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (11).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (12).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (13).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (14).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (15).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (16).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (17).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (18).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (19).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (20).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (21).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (22).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (23).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (24).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (25).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (26).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (27).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (28).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (29).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (30).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (31).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (32).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (33).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (34).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (35).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (36).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (37).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (38).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (39).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (40).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (41).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (42).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (43).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (44).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (45).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (46).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (47).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (48).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (49).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (50).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (51).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (52).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (53).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (54).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (55).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (56).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (57).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (58).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (59).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (60).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (61).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (62).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (63).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (64).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (65).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (66).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (67).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (68).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (69).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (70).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (71).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (72).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (73).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (74).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (75).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (76).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (77).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (78).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (79).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (1).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (2).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (3).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (4).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (5).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (6).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (7).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (8).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (9).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (10).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (11).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (12).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (13).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (14).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (15).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (16).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (17).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (18).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (19).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (20).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (21).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (22).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (23).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (24).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (25).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (26).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (27).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (28).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (29).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (30).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (31).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (32).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (33).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (34).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (35).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (36).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (37).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (38).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (39).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (40).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (41).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (42).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (43).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (44).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (45).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (46).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (47).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (48).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (49).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (50).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (51).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (52).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (53).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (54).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (55).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (56).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (57).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (58).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (59).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (60).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (61).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (62).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (63).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (64).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (65).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (66).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (67).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (68).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (69).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (70).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (71).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (72).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (73).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (74).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (75).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (76).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (77).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (78).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (79).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (1).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (2).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (3).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (4).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (5).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (6).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (7).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (8).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (9).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (10).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (11).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (12).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (13).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (14).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (15).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (16).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (17).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (18).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (19).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (20).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (21).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (22).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (23).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (24).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (25).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (26).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (27).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (28).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (29).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (30).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (31).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (32).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (33).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (34).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (35).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (36).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (37).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (38).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (39).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (40).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (41).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (42).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (43).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (44).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (45).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (46).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (47).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (48).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (49).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (50).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (51).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (52).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (53).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (54).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (55).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (56).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (57).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (58).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (59).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (60).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (61).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (62).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (63).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (64).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (65).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (66).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (67).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (68).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (69).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (70).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (71).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (72).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (73).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (74).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (75).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (76).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (77).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (78).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (79).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (1).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (2).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (3).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (4).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (5).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (6).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (7).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (8).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (9).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (10).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (11).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (12).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (13).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (14).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (15).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (16).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (17).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (18).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (19).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (20).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (21).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (22).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (23).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (24).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (25).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (26).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (27).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (28).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (29).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (30).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (31).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (32).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (33).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (34).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (35).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (36).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (37).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (38).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (39).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (40).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (41).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (42).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (43).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (44).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (45).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (46).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (47).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (48).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (49).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (50).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (51).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (52).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (53).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (54).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (55).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (56).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (57).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (58).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (59).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (60).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (61).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (62).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (63).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (64).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (65).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (66).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (67).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (68).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (69).json
# Error
# /Users/gstarek/Desktop/playbook/training_data/slants/data (70).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (71).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (72).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (73).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (74).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (75).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (76).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (77).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (78).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (79).json

# %%
#test_x, test_y = process_data(80,101)
test_x, test_y = process_data(80,101, reverse='yes')
# Out:
# /Users/gstarek/Desktop/playbook/training_data/posts/data (80).json
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   app.launch_new_instance()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:24: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /Users/gstarek/Desktop/playbook/training_data/posts/data (81).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (82).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (83).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (84).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (85).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (86).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (87).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (88).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (89).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (90).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (91).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (92).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (93).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (94).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (95).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (96).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (97).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (98).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (99).json
# /Users/gstarek/Desktop/playbook/training_data/posts/data (100).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (80).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (81).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (82).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (83).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (84).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (85).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (86).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (87).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (88).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (89).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (90).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (91).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (92).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (93).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (94).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (95).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (96).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (97).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (98).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (99).json
# /Users/gstarek/Desktop/playbook/training_data/hitches/data (100).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (80).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (81).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (82).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (83).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (84).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (85).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (86).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (87).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (88).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (89).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (90).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (91).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (92).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (93).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (94).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (95).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (96).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (97).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (98).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (99).json
# /Users/gstarek/Desktop/playbook/training_data/benders/data (100).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (80).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (81).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (82).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (83).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (84).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (85).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (86).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (87).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (88).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (89).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (90).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (91).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (92).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (93).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (94).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (95).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (96).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (97).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (98).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (99).json
# /Users/gstarek/Desktop/playbook/training_data/fades/data (100).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (80).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (81).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (82).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (83).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (84).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (85).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (86).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (87).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (88).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (89).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (90).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (91).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (92).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (93).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (94).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (95).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (96).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (97).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (98).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (99).json
# /Users/gstarek/Desktop/playbook/training_data/slants/data (100).json

# %%
model = SGDClassifier(random_state=42, max_iter=1000, tol=1e-3)
model.fit(X, Y)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=1000, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=0.001, verbose=0, warm_start=False)

# %%
preds = model.predict(test_x)
conf_matrix = pd.DataFrame(confusion_matrix(test_y, preds), columns = np.unique([test_y]))
conf_matrix.rename({0: conf_matrix.columns[0], 1: conf_matrix.columns[1], 
                       2: conf_matrix.columns[2], 3: conf_matrix.columns[3],
                       4: conf_matrix.columns[4]})
# Out:
#          benders  fades  hitches  posts  slants
# benders       21      0        0      0       0
# fades          0     18        0      3       0
# hitches        0      1       19      1       0
# posts          0      1        0     20       0
# slants         0      0        0      0      21

# %%
preds = model.predict(test_x)
conf_matrix = pd.DataFrame(confusion_matrix(test_y, preds), columns = np.unique([test_y]))
conf_matrix.rename({0: conf_matrix.columns[0], 1: conf_matrix.columns[1], 
                       2: conf_matrix.columns[2], 3: conf_matrix.columns[3],
                       4: conf_matrix.columns[4], 5: conf_matrix.columns[5],
                       6: conf_matrix.columns[6], 7: conf_matrix.columns[7],
                       8: conf_matrix.columns[8], 9: conf_matrix.columns[9]})
# Out:
#                benders_left  benders_right  fades_left  fades_right  \
# benders_left             21              0           0            0
# benders_right             0             21           0            0
# fades_left                0              0          19            0
# fades_right               0              0           0           18
# hitches_left              0              0           1            0
# hitches_right             0              0           0            0
# posts_left                0              0           2            0
# posts_right               0              0           0            2
# slants_left               0              0           0            0
# slants_right              0              0           0            0
#
#                hitches_left  hitches_right  posts_left  posts_right  \
# benders_left              0              0           0            0
# benders_right             0              0           0            0
# fades_left                0              0           2            0
# fades_right               0              0           0            3
# hitches_left             19              0           1            0
# hitches_right             0             20           0            1
# posts_left                0              0          19            0
# posts_right               0              0           0           19
# slants_left               0              0           0            0
# slants_right              0              0           0            0
#
#                slants_left  slants_right
# benders_left             0             0
# benders_right            0             0
# fades_left               0             0
# fades_right              0             0
# hitches_left             0             0
# hitches_right            0             0
# posts_left               0             0
# posts_right              0             0
# slants_left             21             0
# slants_right             0            21

# %%
predict_play("/Users/gstarek/Downloads/data (1).json")
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# blue ['hitches_right']
# Error
# Error
# Error
# yellow ['benders_right']

# %%
def predict_play(json_file):
    canvas_height = 400
    canvas_width = 600
    for color in ['blue', 'orange', 'green', 'purple', 'yellow']:
        df = json_to_df(json_file, canvas_height, canvas_width, color)
        try:
            df = center_df(df, canvas_height, canvas_width)
            x = np.reshape(df.as_matrix(),canvas_height*canvas_width*2)
        except:
            print("Error")
            continue
        print(color, model.predict([x]))

# %%
predict_play("/Users/gstarek/Downloads/data (3).json")
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:34: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# blue ['hitches_left']
# orange ['slants_right']
# green ['fades_right']
# purple ['hitches_right']
# yellow ['posts_right']

# %%
for index, row in df.iterrows():
    if sum(row) > 1:
        print(index)
# Out:
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 305
# 306
# 307
# 311
# 312
# 313
# 317
# 318
# 319
# 324
# 325
# 326
# 335
# 336
# 337
# 343
# 344
# 345
# 350
# 351
# 352
# 360
# 361
# 362
# 375
# 376
# 377
# 383
# 384
# 385
# 390
# 391
# 392
# 394
# 395
# 396
# 397
# 398
# 399

# %%
row[-1::]
# Out:
# 1199    0.0
# Name: 399, dtype: float64

# %%
for index, row in df[-1::].iterrows():
    if sum(row) > 0:
        print(index, sum(row))
# Out:
# 399 3.0

# %%
for index, row in df[::-1].iterrows():
    if sum(row) > 0:
        print(index, sum(row))
# Out:
# 399 3.0
# 398 3.0
# 397 3.0
# 396 3.0
# 395 3.0
# 394 3.0
# 392 3.0
# 391 3.0
# 390 3.0
# 385 3.0
# 384 3.0
# 383 3.0
# 377 3.0
# 376 3.0
# 375 3.0
# 362 3.0
# 361 3.0
# 360 3.0
# 352 3.0
# 351 3.0
# 350 3.0
# 345 3.0
# 344 3.0
# 343 3.0
# 337 3.0
# 336 3.0
# 335 3.0
# 326 3.0
# 325 3.0
# 324 3.0
# 319 3.0
# 318 3.0
# 317 3.0
# 313 3.0
# 312 3.0
# 311 3.0
# 307 3.0
# 306 3.0
# 305 3.0
# 302 3.0
# 301 3.0
# 300 3.0
# 299 6.0
# 298 6.0
# 297 6.0
# 296 6.0
# 295 8.0
# 294 8.0
# 293 7.0
# 292 7.0
# 291 7.0
# 290 5.0
# 289 5.0
# 288 5.0
# 287 3.0
# 286 3.0
# 285 3.0
# 284 3.0

# %%
poss = df[::-1].sort_index()

# %%
for i,v in enumerate(df.ix[284]):
    if v > 0:
        print(i,v)
# Out:
# 596 1.0
# 597 1.0
# 598 1.0
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
for i,v in enumerate(poss.ix[284]):
    if v > 0:
        print(i,v)
# Out:
# 596 1.0
# 597 1.0
# 598 1.0
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
for index, row in df.ix[284].iterrows():
    print(index, row)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-952fdbfac7a0> in <module>()
# ----> 1 for index, row in df.ix[284].iterrows():
#       2     print(index, row)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
##Reversing DataFrame isn't working as expected. Need a better mirror image solution.
